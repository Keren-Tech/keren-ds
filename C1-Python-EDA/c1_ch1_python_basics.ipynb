# %% [markdown]
# <a href="https://colab.research.google.com/github/Keren-Tech/keren-ds/blob/main/C1-Python-EDA/c1_ch1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science.")
# Out:
# Hello, Data Science.

# %% [markdown]
# C1 Chapter 1 - Python Basics
#
# DS Week 1 . March 2026 . Keren Priya Darshini

# %%
print("Starting C1 - Python + EDA")
# Out:
# Starting C1 - Python + EDA
